# %%
import os 
from pathlib import Path
from dotenv import load_dotenv
import nest_asyncio
import sys

# %%
nest_asyncio.apply()


project_root = Path.cwd().parent
sys.path.insert(0, str(project_root / "src"))

load_dotenv(project_root / ".env")


openrouter_key = os.getenv("OPENROUTER_API_KEY")
openai_api_key = os.getenv("OPENAI_API_KEY")


if not openrouter_key and not openai_api_key:
    raise ValueError("OPENROUTER_API_KEY or OPENAI_API_KEY not found in .env file")


provider = "Openrouter" if openrouter_key else "OpenAI"

print("✅ Environment loaded")
print(f"🌐 Provider: {provider}")
print(f"📁 Project root: {project_root}")
# Out:
# ✅ Environment loaded
# 🌐 Provider: Openrouter
# 📁 Project root: d:\ai\bootcamp\mini-project-02\real_state

# %%
from real_state import DATA_DIR, validate, dump, BASE_URL

try:
    validate()
    dump()
except Exception as e:
    print(f"Error: {e}")
    sys.exit(1)
# Out:
# ============================================================
# CONFIGURATION (NON-SECRETS ONLY)
# ============================================================
#
# 🌐 Provider:
#    Provider: openrouter
#    Model Tier: general
#    Chat Model: google/gemini-2.5-flash
#    Embedding Model: google/gemini-embedding-001
#
# 📁 Directories:
#    Data Root: d:\ai\bootcamp\mini-project-02\real_state\data
#    Vector Store: d:\ai\bootcamp\mini-project-02\real_state\data\vector_store
#    Markdown: d:\ai\bootcamp\mini-project-02\real_state\data\primeland_markdown
#    Cache: d:\ai\bootcamp\mini-project-02\real_state\data\cag_cache
#
# 🔧 Chunking:
#    Fixed Size: 800 tokens
#    Fixed Overlap: 100 tokens
#    Sliding Window: 512 tokens
#    Sliding Stride: 256 tokens
#    Parent-Child: 250 → 1200 tokens
#    Late Chunk: 1000 → 300 tokens
#
# 🔍 Retrieval:
#    Top-K Results: 4
#    Similarity Threshold: 0.7
#
# 💾 CAG:
#    Cache TTL: 86400s
#    Max Cache Size: 1000
#
# 🎯 CRAG:
#    Confidence Threshold: 0.6
#    Expanded K: 8
#
# ============================================================

# %%
# !pip install playwright
# Out:
# Collecting playwright
#   Downloading playwright-1.58.0-py3-none-win_amd64.whl.metadata (3.5 kB)
# Collecting pyee<14,>=13 (from playwright)
#   Downloading pyee-13.0.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in d:\ai\qasystem\venv\lib\site-packages (from playwright) (3.2.4)
# Requirement already satisfied: typing-extensions in d:\ai\qasystem\venv\lib\site-packages (from pyee<14,>=13->playwright) (4.14.1)
# Downloading playwright-1.58.0-py3-none-win_amd64.whl (36.8 MB)
#    ---------------------------------------- 0.0/36.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.8 MB ? eta -:--:--
#     --------------------------------------- 0.5/36.8 MB 1.9 MB/s eta 0:00:20
#    - -------------------------------------- 1.0/36.8 MB 2.2 MB/s eta 0:00:17
#    - -------------------------------------- 1.6/36.8 MB 2.2 MB/s eta 0:00:16
#    -- ------------------------------------- 2.1/36.8 MB 2.3 MB/s eta 0:00:16
#    -- ------------------------------------- 2.6/36.8 MB 2.4 MB/s eta 0:00:15
#    --- ------------------------------------ 2.9/36.8 MB 2.4 MB/s eta 0:00:15
#    --- ------------------------------------ 3.4/36.8 MB 2.3 MB/s eta 0:00:15
#    ---- ----------------------------------- 3.9/36.8 MB 2.3 MB/s eta 0:00:15
#    ----- ---------------------------------- 4.7/36.8 MB 2.4 MB/s eta 0:00:14
#    ----- ---------------------------------- 5.0/36.8 MB 2.3 MB/s eta 0:00:14
#    ------ --------------------------------- 5.8/36.8 MB 2.4 MB/s eta 0:00:13
#    ------ --------------------------------- 6.3/36.8 MB 2.4 MB/s eta 0:00:13
#    ------- -------------------------------- 6.8/36.8 MB 2.4 MB/s eta 0:00:13
#    ------- -------------------------------- 7.3/36.8 MB 2.4 MB/s eta 0:00:13
#    -------- ------------------------------- 7.9/36.8 MB 2.4 MB/s eta 0:00:12
#    --------- ------------------------------ 8.4/36.8 MB 2.4 MB/s eta 0:00:12
#    --------- ------------------------------ 8.9/36.8 MB 2.5 MB/s eta 0:00:12
#    ---------- ----------------------------- 9.4/36.8 MB 2.5 MB/s eta 0:00:12
#    ---------- ----------------------------- 10.0/36.8 MB 2.5 MB/s eta 0:00:11
#    ----------- ---------------------------- 10.5/36.8 MB 2.5 MB/s eta 0:00:11
#    ------------ --------------------------- 11.3/36.8 MB 2.5 MB/s eta 0:00:11
#    ------------ --------------------------- 11.8/36.8 MB 2.5 MB/s eta 0:00:10
#    ------------- -------------------------- 12.3/36.8 MB 2.5 MB/s eta 0:00:10
#    -------------- ------------------------- 13.1/36.8 MB 2.6 MB/s eta 0:00:10
#    -------------- ------------------------- 13.6/36.8 MB 2.5 MB/s eta 0:00:10
#    --------------- ------------------------ 13.9/36.8 MB 2.5 MB/s eta 0:00:10
#    --------------- ------------------------ 14.4/36.8 MB 2.5 MB/s eta 0:00:09
#    ---------------- ----------------------- 14.9/36.8 MB 2.5 MB/s eta 0:00:09
#    ---------------- ----------------------- 15.5/36.8 MB 2.5 MB/s eta 0:00:09
#    ----------------- ---------------------- 16.0/36.8 MB 2.5 MB/s eta 0:00:09
#    ----------------- ---------------------- 16.5/36.8 MB 2.5 MB/s eta 0:00:09
#    ------------------ --------------------- 17.0/36.8 MB 2.5 MB/s eta 0:00:08
#    ------------------- -------------------- 17.6/36.8 MB 2.5 MB/s eta 0:00:08
#    ------------------- -------------------- 18.1/36.8 MB 2.5 MB/s eta 0:00:08
#    ------------------- -------------------- 18.4/36.8 MB 2.5 MB/s eta 0:00:08
#    -------------------- ------------------- 18.9/36.8 MB 2.4 MB/s eta 0:00:08
#    --------------------- ------------------ 19.4/36.8 MB 2.4 MB/s eta 0:00:08
#    --------------------- ------------------ 19.7/36.8 MB 2.4 MB/s eta 0:00:08
#    ---------------------- ----------------- 20.4/36.8 MB 2.4 MB/s eta 0:00:07
#    ---------------------- ----------------- 21.0/36.8 MB 2.5 MB/s eta 0:00:07
#    ----------------------- ---------------- 21.5/36.8 MB 2.5 MB/s eta 0:00:07
#    ----------------------- ---------------- 22.0/36.8 MB 2.5 MB/s eta 0:00:07
#    ------------------------ --------------- 22.5/36.8 MB 2.5 MB/s eta 0:00:06
#    ------------------------- -------------- 23.1/36.8 MB 2.4 MB/s eta 0:00:06
#    ------------------------- -------------- 23.6/36.8 MB 2.4 MB/s eta 0:00:06
#    -------------------------- ------------- 24.1/36.8 MB 2.4 MB/s eta 0:00:06
#    -------------------------- ------------- 24.4/36.8 MB 2.4 MB/s eta 0:00:06
#    --------------------------- ------------ 24.9/36.8 MB 2.4 MB/s eta 0:00:05
#    --------------------------- ------------ 25.4/36.8 MB 2.4 MB/s eta 0:00:05
#    --------------------------- ------------ 25.7/36.8 MB 2.4 MB/s eta 0:00:05
#    ---------------------------- ----------- 26.2/36.8 MB 2.4 MB/s eta 0:00:05
#    ----------------------------- ---------- 26.7/36.8 MB 2.4 MB/s eta 0:00:05
#    ----------------------------- ---------- 27.0/36.8 MB 2.4 MB/s eta 0:00:05
#    ------------------------------ --------- 27.8/36.8 MB 2.4 MB/s eta 0:00:04
#    ------------------------------ --------- 28.0/36.8 MB 2.4 MB/s eta 0:00:04
#    ------------------------------ --------- 28.0/36.8 MB 2.4 MB/s eta 0:00:04
#    ------------------------------ --------- 28.3/36.8 MB 2.3 MB/s eta 0:00:04
#    ------------------------------- -------- 28.8/36.8 MB 2.3 MB/s eta 0:00:04
#    ------------------------------- -------- 29.4/36.8 MB 2.3 MB/s eta 0:00:04
#    -------------------------------- ------- 29.9/36.8 MB 2.3 MB/s eta 0:00:03
#    --------------------------------- ------ 30.4/36.8 MB 2.3 MB/s eta 0:00:03
#    --------------------------------- ------ 30.9/36.8 MB 2.3 MB/s eta 0:00:03
#    ---------------------------------- ----- 31.5/36.8 MB 2.3 MB/s eta 0:00:03
#    ---------------------------------- ----- 32.0/36.8 MB 2.3 MB/s eta 0:00:03
#    ----------------------------------- ---- 32.5/36.8 MB 2.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 32.8/36.8 MB 2.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 33.0/36.8 MB 2.3 MB/s eta 0:00:02
#    ------------------------------------ --- 33.6/36.8 MB 2.3 MB/s eta 0:00:02
#    ------------------------------------- -- 34.1/36.8 MB 2.3 MB/s eta 0:00:02
#    ------------------------------------- -- 34.9/36.8 MB 2.3 MB/s eta 0:00:01
#    -------------------------------------- - 35.4/36.8 MB 2.3 MB/s eta 0:00:01
#    -------------------------------------- - 35.7/36.8 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------  36.4/36.8 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 36.8/36.8 MB 2.3 MB/s eta 0:00:00
# Downloading pyee-13.0.1-py3-none-any.whl (15 kB)
# Installing collected packages: pyee, playwright
#
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    ---------------------------------------- 2/2 [playwright]
#
# Successfully installed playwright-1.58.0 pyee-13.0.1

# %%
from playwright.async_api import async_playwright
from collections import deque


start_urls = [
    "https://primelands.lk/",
    "https://primelands.lk/land"
]
visited = []
queue = deque([(url, 0) for url in start_urls])

async with async_playwright() as p:
    browser = await p.chromium.launch(headless=True)
    page = await browser.new_page()
    page.set_default_timeout(30000)

    while queue:
        url, depth = queue.popleft()

        if depth > 3:
            continue

        try:
            print(f"[{depth}] {url}")

        except:
            print("error")
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[2], line 12
#       9 visited = []
#      10 queue = deque([(url, 0) for url in start_urls])
# ---> 12 async with async_playwright() as p:
#      13     browser = await p.chromium.launch(headless=True)
#      14     page = await browser.new_page()
#
# File d:\ai\bootcamp\mini-project-02\real_state\.venv\Lib\site-packages\playwright\async_api\_context_manager.py:46, in PlaywrightContextManager.__aenter__(self)
#      44 if not playwright_future.done():
#      45     playwright_future.cancel()
# ---> 46 playwright = AsyncPlaywright(next(iter(done)).result())
#      47 playwright.stop = self.__aexit__  # type: ignore
#      48 return playwright
#
# File d:\ai\bootcamp\mini-project-02\real_state\.venv\Lib\site-packages\playwright\_impl\_transport.py:120, in PipeTransport.connect(self)
#     117         startupinfo.wShowWindow = subprocess.SW_HIDE
#     119     executable_path, entrypoint_path = compute_driver_executable()
# --> 120     self._proc = await asyncio.create_subprocess_exec(
#     121         executable_path,
#     122         entrypoint_path,
#     123         "run-driver",
#     124         stdin=asyncio.subprocess.PIPE,
#     125         stdout=asyncio.subprocess.PIPE,
#     126         stderr=_get_stderr_fileno(),
#     127         limit=32768,
#     128         env=env,
#     129         startupinfo=startupinfo,
#     130     )
#     131 except Exception as exc:
#     132     self.on_error_future.set_exception(exc)
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.5-windows-x86_64-none\Lib\asyncio\subprocess.py:224, in create_subprocess_exec(program, stdin, stdout, stderr, limit, *args, **kwds)
#     221 loop = events.get_running_loop()
#     222 protocol_factory = lambda: SubprocessStreamProtocol(limit=limit,
#     223                                                     loop=loop)
# --> 224 transport, protocol = await loop.subprocess_exec(
#     225     protocol_factory,
#     226     program, *args,
#     227     stdin=stdin, stdout=stdout,
#     228     stderr=stderr, **kwds)
#     229 return Process(transport, protocol, loop)
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.5-windows-x86_64-none\Lib\asyncio\base_events.py:1794, in BaseEventLoop.subprocess_exec(self, protocol_factory, program, stdin, stdout, stderr, universal_newlines, shell, bufsize, encoding, errors, text, *args, **kwargs)
#    1792     debug_log = f'execute program {program!r}'
#    1793     self._log_subprocess(debug_log, stdin, stdout, stderr)
# -> 1794 transport = await self._make_subprocess_transport(
#    1795     protocol, popen_args, False, stdin, stdout, stderr,
#    1796     bufsize, **kwargs)
#    1797 if self._debug and debug_log is not None:
#    1798     logger.info('%s: %r', debug_log, transport)
#
# File ~\AppData\Roaming\uv\python\cpython-3.13.5-windows-x86_64-none\Lib\asyncio\base_events.py:539, in BaseEventLoop._make_subprocess_transport(self, protocol, args, shell, stdin, stdout, stderr, bufsize, extra, **kwargs)
#     535 async def _make_subprocess_transport(self, protocol, args, shell,
#     536                                      stdin, stdout, stderr, bufsize,
#     537                                      extra=None, **kwargs):
#     538     """Create subprocess transport."""
# --> 539     raise NotImplementedError
#
# NotImplementedError:
